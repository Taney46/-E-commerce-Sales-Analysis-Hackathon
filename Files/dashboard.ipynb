# %%
import pandas as pd
from sqlalchemy import create_engine

# Database connection 
db_username = "root"
db_password = "velvexita3*"
db_host = "localhost"
db_name = "hackathon"

# Creating connection
engine = create_engine(f"mysql+pymysql://{db_username}:{db_password}@{db_host}/{db_name}")

# Fetching data from SQL table
query = "SELECT * FROM sales_data"  
df = pd.read_sql(query, engine)


print(df.head())
# Out:
#    CustomerNo CustomerID  Gender Region  Age ProductName     Category  \
# 0           1   CUST0046    Male   West   22  Headphones  Accessories
# 1           2   CUST0169  Female  South   54     Monitor  Electronics
# 2           3   CUST0002    Male  North   23  Headphones  Accessories
# 3           4   CUST0147    Male  North   64  Smartwatch    Wearables
# 4           5   CUST0262    Male   East   27  Smartwatch    Wearables
#
#    UnitPrice  Quantity  TotalPrice  ShippingFee ShippingStatus   OrderDate
# 0        100         2         200         6.93     In Transit    4/9/2023
# 1        300         1         300        11.31       Returned   8/28/2023
# 2        100         5         500        12.22      Delivered   1/18/2023
# 3        200         2         400        11.26     In Transit   1/11/2023
# 4        200         1         200        18.38     In Transit  10/23/2023

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset with error handling
def load_data():
    try:
        df = pd.read_csv(r"C:\Hackathon\-E-commerce-Sales-Analysis-Hackathon\sales_data.csv")  
        if 'OrderDate' in df.columns:
            df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')
        return df
    except Exception as e:
        st.error(f"Error loading data: {e}")
        return pd.DataFrame()

df = load_data()

if df.empty:
    st.stop()

# Sidebar Filters
st.sidebar.header("Filter Data")
if 'Category' in df.columns:
    selected_category = st.sidebar.multiselect("Select Category", df['Category'].dropna().unique())
else:
    selected_category = []

if 'Region' in df.columns:
    selected_region = st.sidebar.multiselect("Select Region", df['Region'].dropna().unique())
else:
    selected_region = []

# Apply filters
if selected_category:
    df = df[df['Category'].isin(selected_category)]
if selected_region:
    df = df[df['Region'].isin(selected_region)]

# Main Dashboard
st.title("📊 E-Commerce Sales Dashboard")

# Sales Overview
if 'TotalPrice' in df.columns:
    st.subheader("💰 Sales Overview")
    total_sales = df['TotalPrice'].sum()
    avg_order_value = df['TotalPrice'].mean()
    st.metric("Total Sales", f"${total_sales:,.2f}")
    st.metric("Average Order Value", f"${avg_order_value:,.2f}")

# Top-Selling Products
if 'ProductName' in df.columns:
    st.subheader("🏆 Top 5 Best-Selling Products")
    top_products = df.groupby('ProductName')['TotalPrice'].sum().sort_values(ascending=False).head(5)
    st.bar_chart(top_products)

# Monthly Sales Trend
if 'OrderDate' in df.columns and 'TotalPrice' in df.columns:
    st.subheader("📈 Monthly Sales Trend")
    monthly_sales = df.resample('ME', on='OrderDate')['TotalPrice'].sum()
    monthly_sales.index = monthly_sales.index.strftime('%Y-%m')
    st.line_chart(monthly_sales)

# Customer Segmentation
if 'Gender' in df.columns:
    st.subheader("👥 Customer Spending by Gender")
    gender_spending = df.groupby('Gender')['TotalPrice'].mean()
    fig, ax = plt.subplots()
    sns.barplot(x=gender_spending.index, y=gender_spending.values, ax=ax, hue=gender_spending.index, palette="coolwarm")
    ax.set_title("Average Spending per Customer by Gender")
    ax.set_xlabel("Gender")
    ax.set_ylabel("Average Total Price")
    st.pyplot(fig)

# Shipping Performance
if 'ShippingStatus' in df.columns:
    st.subheader("🚚 Shipping Performance")
    shipping_status_counts = df['ShippingStatus'].value_counts()
    fig, ax = plt.subplots()
    sns.barplot(x=shipping_status_counts.index, y=shipping_status_counts.values, ax=ax, hue=shipping_status_counts.index, palette="viridis")
    ax.set_title("Shipping Performance")
    ax.set_xlabel("Shipping Status")
    ax.set_ylabel("Number of Orders")
    st.pyplot(fig)

# Insights
st.write("### 📌 Insights")
st.write("- Focus on best-selling products to boost sales.")
st.write("- Identify top-performing regions for marketing campaigns.")
st.write("- Monitor seasonal trends for better inventory planning.")
st.write("- Improve shipping times to enhance customer satisfaction.")

st.write("---")
st.write("🔍 _Explore the data dynamically using the filters in the sidebar._")
# Out:
# 2025-03-26 19:23:29.219 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.526
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-03-26 19:23:34.529 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.533 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.536 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.540 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.543 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.546 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.550 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.554 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.558 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.561 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.572 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.577 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.584 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.587 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.591 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.593 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.599 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.602 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.610 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:34.614 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.117 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.120 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.124 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.129 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.396 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.398 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.402 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.406 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:40.660 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.328 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.330 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.333 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.338 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.542 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.932 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.935 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.939 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.942 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.945 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.950 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.953 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.956 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.961 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.965 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.973 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.980 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.988 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.995 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:41.999 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.005 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.008 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.019 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.026 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.033 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.042 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.047 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.050 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.056 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.059 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.062 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.066 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.069 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 19:23:42.073 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
