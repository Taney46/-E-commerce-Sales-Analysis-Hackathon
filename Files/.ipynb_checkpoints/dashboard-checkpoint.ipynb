# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset with error handling
def load_data():
    try:
        df = pd.read_csv(r"C:\Hackathon\-E-commerce-Sales-Analysis-Hackathon\sales_data.csv")  
        if 'OrderDate' in df.columns:
            df['OrderDate'] = pd.to_datetime(df['OrderDate'], errors='coerce')
        return df
    except Exception as e:
        st.error(f"Error loading data: {e}")
        return pd.DataFrame()

df = load_data()

if df.empty:
    st.stop()

# Sidebar Filters
st.sidebar.header("Filter Data")
if 'Category' in df.columns:
    selected_category = st.sidebar.multiselect("Select Category", df['Category'].dropna().unique())
else:
    selected_category = []

if 'Region' in df.columns:
    selected_region = st.sidebar.multiselect("Select Region", df['Region'].dropna().unique())
else:
    selected_region = []

# Apply filters
if selected_category:
    df = df[df['Category'].isin(selected_category)]
if selected_region:
    df = df[df['Region'].isin(selected_region)]

# Main Dashboard
st.title("📊 E-Commerce Sales Dashboard")

# Sales Overview
if 'TotalPrice' in df.columns:
    st.subheader("💰 Sales Overview")
    total_sales = df['TotalPrice'].sum()
    avg_order_value = df['TotalPrice'].mean()
    st.metric("Total Sales", f"${total_sales:,.2f}")
    st.metric("Average Order Value", f"${avg_order_value:,.2f}")

# Top-Selling Products
if 'ProductName' in df.columns:
    st.subheader("🏆 Top 5 Best-Selling Products")
    top_products = df.groupby('ProductName')['TotalPrice'].sum().sort_values(ascending=False).head(5)
    st.bar_chart(top_products)

# Monthly Sales Trend
if 'OrderDate' in df.columns and 'TotalPrice' in df.columns:
    st.subheader("📈 Monthly Sales Trend")
    monthly_sales = df.resample('ME', on='OrderDate')['TotalPrice'].sum()
    monthly_sales.index = monthly_sales.index.strftime('%Y-%m')
    st.line_chart(monthly_sales)

# Customer Segmentation
if 'Gender' in df.columns:
    st.subheader("👥 Customer Spending by Gender")
    gender_spending = df.groupby('Gender')['TotalPrice'].mean()
    fig, ax = plt.subplots()
    sns.barplot(x=gender_spending.index, y=gender_spending.values, ax=ax, hue=gender_spending.index, palette="coolwarm")
    ax.set_title("Average Spending per Customer by Gender")
    ax.set_xlabel("Gender")
    ax.set_ylabel("Average Total Price")
    st.pyplot(fig)

# Shipping Performance
if 'ShippingStatus' in df.columns:
    st.subheader("🚚 Shipping Performance")
    shipping_status_counts = df['ShippingStatus'].value_counts()
    fig, ax = plt.subplots()
    sns.barplot(x=shipping_status_counts.index, y=shipping_status_counts.values, ax=ax, hue=shipping_status_counts.index, palette="viridis")
    ax.set_title("Shipping Performance")
    ax.set_xlabel("Shipping Status")
    ax.set_ylabel("Number of Orders")
    st.pyplot(fig)

# Insights
st.write("### 📌 Insights")
st.write("- Focus on best-selling products to boost sales.")
st.write("- Identify top-performing regions for marketing campaigns.")
st.write("- Monitor seasonal trends for better inventory planning.")
st.write("- Improve shipping times to enhance customer satisfaction.")

st.write("---")
st.write("🔍 _Explore the data dynamically using the filters in the sidebar._")
# Out:
# 2025-03-26 18:20:34.046 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.349
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-03-26 18:20:37.352 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.362 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.366 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.374 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.382 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.386 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.417 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.420 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.424 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.427 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.429 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.433 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.435 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.437 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.442 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.445 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:37.447 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.385 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.400 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.404 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.657 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.661 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.662 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:42.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:43.086 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.094 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.099 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.101 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.291 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.716 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.718 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.719 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.721 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.726 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.729 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.733 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.735 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.737 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.739 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.743 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.746 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.748 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.750 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.752 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.754 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.759 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.763 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.765 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.767 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.769 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.772 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.776 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.778 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.783 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.788 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.792 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-03-26 18:20:44.794 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
